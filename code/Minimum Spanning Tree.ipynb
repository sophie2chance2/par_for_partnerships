# %%
import numpy as np
import pandas as pd
import itertools

import neo4j
import psycopg2

from geographiclib.geodesic import Geodesic

# %% [markdown]
# # Load data on chosen golf courses and their coordinates

# %%
courses_df = pd.read_csv("../data/chosen_courses.csv", usecols=['golf_course'])
geo_df = pd.read_csv("../data/distance_data.csv", usecols=['golf_course', 'golf_course_geo'])

courses_geo_df = pd.merge(courses_df, geo_df, on='golf_course', how='left')
courses_geo_df = courses_geo_df.drop_duplicates().reset_index(drop=True)
courses_geo_df
# Out:
#                             golf_course                  golf_course_geo
# 0       Trump Golf Links At Ferry Point          (40.812471, -73.834446)
# 1                            Bulle Rock        (39.5422532, -76.1328107)
# 2                         The Glen Club  (42.090201, -87.82770579999999)
# 3               Streamsong Resort (Red)        (27.6928094, -81.9344824)
# 4         Reynolds Lake Oconee (Oconee)        (33.4398841, -83.1975021)
# 5  Pelican Hill Golf Club (Ocean South)        (33.584694, -117.8403009)
# 6                 Lake Of Isles (North)         (41.4838118, -71.950374)
# 7                  Trump National Doral        (25.8129673, -80.3387175)

# %%
def get_lat_long(point):
    
    "Given string in (lat, long) format, extract list of floats in [lat, long] format"
    
    init_split = point.split('(')[1].split(',')
    lat = init_split[0]
    long = init_split[1].split(')')[0]
    
    return [float(lat), float(long)]

# %%
def calculate_distance(point_1, point_2):
    "Given two points in (latitude, longitude) format, calculate the distance between them in miles, using ellipsoid distnace for accuracy"
    
    geod = Geodesic.WGS84

    g = geod.Inverse(point_1[0], point_1[1], point_2[0], point_2[1])
    miles = g['s12'] / 1000 * 0.621371
    
    return miles

# %%
# Get all pairs of courses (excluding duplicates) and make df with corresponding coordinates

courses_pairs = [(c1, c2) for c1 in courses_df['golf_course'] for c2 in courses_df['golf_course'] if c1 != c2]

pairs_geo = []

for pair in courses_pairs:
    pairs_geo.append(
    {
    'Course_A': pair[0],
    'Course_B': pair[1],
    # Get corresponding coordinates as float
    'Geo_A': get_lat_long(courses_geo_df.loc[courses_geo_df['golf_course'] == pair[0], 'golf_course_geo'].iloc[0]),
    'Geo_B': get_lat_long(courses_geo_df.loc[courses_geo_df['golf_course'] == pair[1], 'golf_course_geo'].iloc[0])
    }
)
    
pairs_geo_df = pd.DataFrame(pairs_geo)
pairs_geo_df.head()
# Out:
#                           Course_A                              Course_B  \
# 0  Trump Golf Links At Ferry Point                            Bulle Rock
# 1  Trump Golf Links At Ferry Point                         The Glen Club
# 2  Trump Golf Links At Ferry Point               Streamsong Resort (Red)
# 3  Trump Golf Links At Ferry Point         Reynolds Lake Oconee (Oconee)
# 4  Trump Golf Links At Ferry Point  Pelican Hill Golf Club (Ocean South)
#
#                      Geo_A                            Geo_B
# 0  [40.812471, -73.834446]        [39.5422532, -76.1328107]
# 1  [40.812471, -73.834446]  [42.090201, -87.82770579999999]
# 2  [40.812471, -73.834446]        [27.6928094, -81.9344824]
# 3  [40.812471, -73.834446]        [33.4398841, -83.1975021]
# 4  [40.812471, -73.834446]        [33.584694, -117.8403009]

# %% [markdown]
# # Calculate distance between each pair

# %%
# Get ellipsoid distance

pairs_geo_df['Distance_crow'] = pairs_geo_df.apply(lambda x: calculate_distance(x.Geo_A, x.Geo_B), axis=1)
pairs_geo_df.head()
# Out:
#                           Course_A                              Course_B  \
# 0  Trump Golf Links At Ferry Point                            Bulle Rock
# 1  Trump Golf Links At Ferry Point                         The Glen Club
# 2  Trump Golf Links At Ferry Point               Streamsong Resort (Red)
# 3  Trump Golf Links At Ferry Point         Reynolds Lake Oconee (Oconee)
# 4  Trump Golf Links At Ferry Point  Pelican Hill Golf Club (Ocean South)
#
#                      Geo_A                            Geo_B  Distance_crow
# 0  [40.812471, -73.834446]        [39.5422532, -76.1328107]     149.912644
# 1  [40.812471, -73.834446]  [42.090201, -87.82770579999999]     731.036255
# 2  [40.812471, -73.834446]        [27.6928094, -81.9344824]    1015.056069
# 3  [40.812471, -73.834446]        [33.4398841, -83.1975021]     724.264110
# 4  [40.812471, -73.834446]        [33.584694, -117.8403009]    2451.735798

# %% [markdown]
# # Neo4j functions from labs

# %%
def my_neo4j_wipe_out_database():
    "wipe out database by deleting all nodes and relationships"
    
    query = "match (node)-[relationship]->() delete node, relationship"
    session.run(query)
    
    query = "match (node) delete node"
    session.run(query)

# %%
def my_neo4j_run_query_pandas(query, **kwargs):
    "run a query and return the results in a pandas dataframe"
    
    result = session.run(query, **kwargs)
    
    df = pd.DataFrame([r.values() for r in result], columns=result.keys())
    
    return df

# %%
def my_neo4j_number_nodes_relationships():
    "print the number of nodes and relationships"
   
    
    query = """
        match (n) 
        return n.name as node_name, labels(n) as labels
        order by n.name
    """
    
    df = my_neo4j_run_query_pandas(query)
    
    number_nodes = df.shape[0]
    
    
    query = """
        match (n1)-[r]->(n2) 
        return n1.name as node_name_1, labels(n1) as node_1_labels, 
            type(r) as relationship_type, n2.name as node_name_2, labels(n2) as node_2_labels
        order by node_name_1, node_name_2
    """
    
    df = my_neo4j_run_query_pandas(query)
    
    number_relationships = df.shape[0]
    
    print("-------------------------")
    print("  Nodes:", number_nodes)
    print("  Relationships:", number_relationships)
    print("-------------------------")
    
    display(df)

# %%
def my_neo4j_create_golf_course_node(golf_course_name):
    "create a node with label Golf_Course"
    
    query = """
    
    CREATE (:Golf_Course {name: $golf_course_name})
    
    """
    
    session.run(query, golf_course_name=golf_course_name)

# %%
def my_neo4j_create_relationship_one_way(from_course, to_course, weight):
    "create a relationship one way between  two golf courses with a weight"
    
    query = """
    
    MATCH (from:Golf_Course), 
          (to:Golf_Course)
    WHERE from.name = $from_course and to.name = $to_course
    CREATE (from)-[:LINK {weight: $weight}]->(to)
    
    """
    
    session.run(query, from_course=from_course, to_course=to_course, weight=weight)

# %%
connection = psycopg2.connect(
    user = "postgres",
    password = "ucb",
    host = "postgres",
    port = "5432",
    database = "postgres"
)

# %%
cursor = connection.cursor()

# %% [markdown]
# # Create graph of golf courses weighted by distance

# %%
# Neo4j setup
driver = neo4j.GraphDatabase.driver(uri="neo4j://neo4j:7687", auth=("neo4j","ucb_mids_w205"))
session = driver.session(database="neo4j")

my_neo4j_wipe_out_database()

# %%
# Check that graph is empty

my_neo4j_number_nodes_relationships()
# Out:
# -------------------------
#   Nodes: 0
#   Relationships: 0
# -------------------------
# Empty DataFrame
# Columns: [node_name_1, node_1_labels, relationship_type, node_name_2, node_2_labels]
# Index: []

# %%
### Create graph of golf courses weighted by distance

# Keep track of nodes to avoid duplicates
nodes = []

for index, row in pairs_geo_df.iterrows():
    
    # Nodes for each golf course
    if row['Course_A'] not in nodes:
        my_neo4j_create_golf_course_node(row['Course_A'])
        nodes.append(row['Course_A'])
    if row['Course_B'] not in nodes:
        my_neo4j_create_golf_course_node(row['Course_B'])
        nodes.append(row['Course_B'])
    
    # Use distance as weight
    weight = row['Distance_crow']
    
    # Create one-way relationships between golf courses
    # Graph will have two-way relationships due to both directions being captured
    my_neo4j_create_relationship_one_way(row['Course_A'], row['Course_B'], weight)

# %%
## View nodes and relationships

my_neo4j_number_nodes_relationships()
# Out:
# -------------------------
#   Nodes: 8
#   Relationships: 56
# -------------------------
#                              node_name_1  node_1_labels relationship_type  \
# 0                             Bulle Rock  [Golf_Course]              LINK
# 1                             Bulle Rock  [Golf_Course]              LINK
# 2                             Bulle Rock  [Golf_Course]              LINK
# 3                             Bulle Rock  [Golf_Course]              LINK
# 4                             Bulle Rock  [Golf_Course]              LINK
# 5                             Bulle Rock  [Golf_Course]              LINK
# 6                             Bulle Rock  [Golf_Course]              LINK
# 7                  Lake Of Isles (North)  [Golf_Course]              LINK
# 8                  Lake Of Isles (North)  [Golf_Course]              LINK
# 9                  Lake Of Isles (North)  [Golf_Course]              LINK
# 10                 Lake Of Isles (North)  [Golf_Course]              LINK
# 11                 Lake Of Isles (North)  [Golf_Course]              LINK
# 12                 Lake Of Isles (North)  [Golf_Course]              LINK
# 13                 Lake Of Isles (North)  [Golf_Course]              LINK
# 14  Pelican Hill Golf Club (Ocean South)  [Golf_Course]              LINK
# 15  Pelican Hill Golf Club (Ocean South)  [Golf_Course]              LINK
# 16  Pelican Hill Golf Club (Ocean South)  [Golf_Course]              LINK
# 17  Pelican Hill Golf Club (Ocean South)  [Golf_Course]              LINK
# 18  Pelican Hill Golf Club (Ocean South)  [Golf_Course]              LINK
# 19  Pelican Hill Golf Club (Ocean South)  [Golf_Course]              LINK
# 20  Pelican Hill Golf Club (Ocean South)  [Golf_Course]              LINK
# 21         Reynolds Lake Oconee (Oconee)  [Golf_Course]              LINK
# 22         Reynolds Lake Oconee (Oconee)  [Golf_Course]              LINK
# 23         Reynolds Lake Oconee (Oconee)  [Golf_Course]              LINK
# 24         Reynolds Lake Oconee (Oconee)  [Golf_Course]              LINK
# 25         Reynolds Lake Oconee (Oconee)  [Golf_Course]              LINK
# 26         Reynolds Lake Oconee (Oconee)  [Golf_Course]              LINK
# 27         Reynolds Lake Oconee (Oconee)  [Golf_Course]              LINK
# 28               Streamsong Resort (Red)  [Golf_Course]              LINK
# 29               Streamsong Resort (Red)  [Golf_Course]              LINK
# 30               Streamsong Resort (Red)  [Golf_Course]              LINK
# 31               Streamsong Resort (Red)  [Golf_Course]              LINK
# 32               Streamsong Resort (Red)  [Golf_Course]              LINK
# 33               Streamsong Resort (Red)  [Golf_Course]              LINK
# 34               Streamsong Resort (Red)  [Golf_Course]              LINK
# 35                         The Glen Club  [Golf_Course]              LINK
# 36                         The Glen Club  [Golf_Course]              LINK
# 37                         The Glen Club  [Golf_Course]              LINK
# 38                         The Glen Club  [Golf_Course]              LINK
# 39                         The Glen Club  [Golf_Course]              LINK
# 40                         The Glen Club  [Golf_Course]              LINK
# 41                         The Glen Club  [Golf_Course]              LINK
# 42       Trump Golf Links At Ferry Point  [Golf_Course]              LINK
# 43       Trump Golf Links At Ferry Point  [Golf_Course]              LINK
# 44       Trump Golf Links At Ferry Point  [Golf_Course]              LINK
# 45       Trump Golf Links At Ferry Point  [Golf_Course]              LINK
# 46       Trump Golf Links At Ferry Point  [Golf_Course]              LINK
# 47       Trump Golf Links At Ferry Point  [Golf_Course]              LINK
# 48       Trump Golf Links At Ferry Point  [Golf_Course]              LINK
# 49                  Trump National Doral  [Golf_Course]              LINK
# 50                  Trump National Doral  [Golf_Course]              LINK
# 51                  Trump National Doral  [Golf_Course]              LINK
# 52                  Trump National Doral  [Golf_Course]              LINK
# 53                  Trump National Doral  [Golf_Course]              LINK
# 54                  Trump National Doral  [Golf_Course]              LINK
# 55                  Trump National Doral  [Golf_Course]              LINK
#
#                              node_name_2  node_2_labels
# 0                  Lake Of Isles (North)  [Golf_Course]
# 1   Pelican Hill Golf Club (Ocean South)  [Golf_Course]
# 2          Reynolds Lake Oconee (Oconee)  [Golf_Course]
# 3                Streamsong Resort (Red)  [Golf_Course]
# 4                          The Glen Club  [Golf_Course]
# 5        Trump Golf Links At Ferry Point  [Golf_Course]
# 6                   Trump National Doral  [Golf_Course]
# 7                             Bulle Rock  [Golf_Course]
# 8   Pelican Hill Golf Club (Ocean South)  [Golf_Course]
# 9          Reynolds Lake Oconee (Oconee)  [Golf_Course]
# 10               Streamsong Resort (Red)  [Golf_Course]
# 11                         The Glen Club  [Golf_Course]
# 12       Trump Golf Links At Ferry Point  [Golf_Course]
# 13                  Trump National Doral  [Golf_Course]
# 14                            Bulle Rock  [Golf_Course]
# 15                 Lake Of Isles (North)  [Golf_Course]
# 16         Reynolds Lake Oconee (Oconee)  [Golf_Course]
# 17               Streamsong Resort (Red)  [Golf_Course]
# 18                         The Glen Club  [Golf_Course]
# 19       Trump Golf Links At Ferry Point  [Golf_Course]
# 20                  Trump National Doral  [Golf_Course]
# 21                            Bulle Rock  [Golf_Course]
# 22                 Lake Of Isles (North)  [Golf_Course]
# 23  Pelican Hill Golf Club (Ocean South)  [Golf_Course]
# 24               Streamsong Resort (Red)  [Golf_Course]
# 25                         The Glen Club  [Golf_Course]
# 26       Trump Golf Links At Ferry Point  [Golf_Course]
# 27                  Trump National Doral  [Golf_Course]
# 28                            Bulle Rock  [Golf_Course]
# 29                 Lake Of Isles (North)  [Golf_Course]
# 30  Pelican Hill Golf Club (Ocean South)  [Golf_Course]
# 31         Reynolds Lake Oconee (Oconee)  [Golf_Course]
# 32                         The Glen Club  [Golf_Course]
# 33       Trump Golf Links At Ferry Point  [Golf_Course]
# 34                  Trump National Doral  [Golf_Course]
# 35                            Bulle Rock  [Golf_Course]
# 36                 Lake Of Isles (North)  [Golf_Course]
# 37  Pelican Hill Golf Club (Ocean South)  [Golf_Course]
# 38         Reynolds Lake Oconee (Oconee)  [Golf_Course]
# 39               Streamsong Resort (Red)  [Golf_Course]
# 40       Trump Golf Links At Ferry Point  [Golf_Course]
# 41                  Trump National Doral  [Golf_Course]
# 42                            Bulle Rock  [Golf_Course]
# 43                 Lake Of Isles (North)  [Golf_Course]
# 44  Pelican Hill Golf Club (Ocean South)  [Golf_Course]
# 45         Reynolds Lake Oconee (Oconee)  [Golf_Course]
# 46               Streamsong Resort (Red)  [Golf_Course]
# 47                         The Glen Club  [Golf_Course]
# 48                  Trump National Doral  [Golf_Course]
# 49                            Bulle Rock  [Golf_Course]
# 50                 Lake Of Isles (North)  [Golf_Course]
# 51  Pelican Hill Golf Club (Ocean South)  [Golf_Course]
# 52         Reynolds Lake Oconee (Oconee)  [Golf_Course]
# 53               Streamsong Resort (Red)  [Golf_Course]
# 54                         The Glen Club  [Golf_Course]
# 55       Trump Golf Links At Ferry Point  [Golf_Course]

# %% [markdown]
# # Minimum Spanning Tree

# %%
def my_neo4j_wipe_out_mst_relationships():
    "wipe out mst relationships"
    
    query = "match (node)-[relationship:MST]->() delete relationship"
    session.run(query)

# %%
my_neo4j_wipe_out_mst_relationships()

# %%
query = "CALL gds.graph.drop('ds_graph', false)"
session.run(query)

query = """

CALL gds.graph.project('ds_graph', 'Golf_Course', 
                        {
                            LINK: {
                                properties: 'weight',
                                orientation: 'UNDIRECTED'
                            }
                        }
                       )

"""

session.run(query)

# %%
query = """

MATCH (n:Golf_Course {name: $source})
CALL gds.beta.spanningTree.write('ds_graph',
                                          {sourceNode: id(n),
                                           relationshipWeightProperty: 'weight',
                                           writeProperty: 'writeCost',
                                           writeRelationshipType: 'MST'
                                          }
                                         )
YIELD preProcessingMillis, computeMillis, writeMillis, effectiveNodeCount
RETURN preProcessingMillis, computeMillis, writeMillis, effectiveNodeCount;

"""

source = courses_df['golf_course'][0] # start at highest weighted golf course

my_neo4j_run_query_pandas(query, source=source)
# Out:
#    preProcessingMillis  computeMillis  writeMillis  effectiveNodeCount
# 0                    0              3            9                   8

# %%
query = """

MATCH path = (n:Golf_Course {name: $source})-[:MST*]-()
WITH relationships(path) AS rels
UNWIND rels AS rel
WITH DISTINCT rel AS rel
RETURN startNode(rel).name AS source, endNode(rel).name AS destination, rel.writeCost AS distance

"""

source = courses_df['golf_course'][0]  # start at highest weighted golf course

min_span_tree = my_neo4j_run_query_pandas(query, source=source)
print(min_span_tree)
# Out:
#                             source                           destination  \
# 0  Trump Golf Links At Ferry Point                            Bulle Rock
# 1                       Bulle Rock                         The Glen Club
# 2                    The Glen Club  Pelican Hill Golf Club (Ocean South)
# 3                       Bulle Rock         Reynolds Lake Oconee (Oconee)
# 4    Reynolds Lake Oconee (Oconee)               Streamsong Resort (Red)
# 5          Streamsong Resort (Red)                  Trump National Doral
# 6  Trump Golf Links At Ferry Point                 Lake Of Isles (North)
#
#       distance
# 0   149.912644
# 1   637.210292
# 2  1732.475319
# 3   575.590317
# 4   402.980517
# 5   162.716933
# 6   108.645461

# %%
# Export Minimum Spanning Tree to CSV

min_span_tree.to_csv('../data/min_span_tree.csv', index=False)
