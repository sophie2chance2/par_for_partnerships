# %% [markdown]
# ## Node Similarity Notebook
#
# - Import CSV files:
#     - Target prospects, which contains potential customers of interest.
#     - Happiest customers, which gives examples of exemplary customers for comparison.
# - Perform data cleaning, identify the columns of interests and the possible different categories for each.

# %%
import pandas as pd
import numpy as np
import neo4j

# %% [markdown]
# Important fields in new data:
#
# Segment
# 	Allied Health
# 	Beauty Wellness
# 	Career Trade
#
# School Type
# 	Private for-profit
#
# Total Student Count
# 	150-10000
#
# LMS
# 	From the screenshot Sophie provided

# %%
prospects = pd.read_csv('../data/target_prospects.csv')

print('Segment categories for prospect schools:\n')
print(prospects['Segment'].value_counts())

print('\n\nSchool types for prospect schools:\n')
print(prospects['School Type (picklist)'].value_counts())

print('\n\nSummary of "Total Students" column:\n')
print(prospects['Total Students'].dropna().str.replace(',','').astype(int).describe())

print('\n\nLMS types for prospect schools:\n')
print(prospects['LMS (multi-select)'].value_counts())
# Out:
# Segment categories for prospect schools:
#
# Beauty + Wellness    291
# Allied Health        175
# Career + Trade        98
# University             1
# Community College      1
# Primary Education      1
# Name: Segment, dtype: int64
#
#
# School types for prospect schools:
#
# Private for-profit    422
# Public                 41
# Not-for-profit         40
# Community College      22
# Name: School Type (picklist), dtype: int64
#
#
# Summary of "Total Students" column:
#
# count      509.000000
# mean      1060.589391
# std       3458.835196
# min          0.000000
# 25%        127.000000
# 50%        300.000000
# 75%        621.000000
# max      51976.000000
# Name: Total Students, dtype: float64
#
#
# LMS types for prospect schools:
#
# PivotPoint                                115
# Canvas                                    110
# Moodle                                     36
# Blackboard                                 19
# Milady                                     15
# D2L                                        12
# None                                        9
# Schoology                                   3
# Clic                                        2
# D2L; Brightspace                            2
# Moodle; Other                               2
# Custom                                      2
# Microsoft                                   2
# Canvas; Moodle                              2
# Cengage                                     1
# Google Classroom                            1
# googlesuit, zoom, webex, ThinkWave          1
# Populi                                      1
# Clic/Homegrown                              1
# Powerschool                                 1
# LERN                                        1
# Clic/Proprietary                            1
# MS365                                       1
# CLIC (Certified Learing in Education)       1
# Ellucian                                    1
# LearnAveda                                  1
# Google classroom                            1
# Proctorio - https://proctorio.com/          1
# Blackboard; Open LMS- A moodle product      1
# Blue Triangle                               1
# Stack Blue                                  1
# Jupiter Ed                                  1
# Milady; Canvas; Cengage                     1
# Evolve Elsevier                             1
# LA Film Online                              1
# Google Classroom/Schoololgy                 1
# Blackboard; Moodle                          1
# Canvas; Microsoft Office 365                1
# Milady; Moodle                              1
# PivotPoint; KlassApp                        1
# Canvas; Other                               1
# Sakai; D2L; Moodle; Other                   1
# D2L; Brighthouse; College Office            1
# Other; Canvas                               1
# PivotPoint; Toni &Guy                       1
# Blackboard; Canvas                          1
# D2L; Other                                  1
# D2L; BrightSpace by D2L                     1
# Moodle; Open LMS (A Moodle Product)         1
# Microsoft Teams                             1
# D2L; bright space                           1
# Home grown                                  1
# NEO                                         1
# Blackboard; Jupiter                         1
# Canvas; Blackboard                          1
# Milady; CLIC ( Proprietary)                 1
# Moodle; Canvas                              1
# SAP Netweaver                               1
# CLIC                                        1
# Name: LMS (multi-select), dtype: int64

# %%
# Load happiest_customers.csv
happiest = pd.read_csv('../data/happiest_customers.csv')

# Save Record IDs of happiest customers to discern them later
happiest_records = happiest['Record ID']

# Merge datasets by concatenating
all_schools = pd.concat([happiest, prospects], ignore_index=True)

# Add a new column to capture whether a school has more or less than 150 students
all_schools['Total Students'] = all_schools['Total Students'].dropna().str.replace(',','').astype(int)
all_schools['total_students_gt_150'] = [student_count >= 150 for student_count in all_schools['Total Students']]

print('Elements in prospects:', len(prospects))
print('Elements in happiest:', len(happiest))
print('Combined length:', len(all_schools))
# Out:
# Elements in prospects: 571
# Elements in happiest: 51
# Combined length: 622

# %%
# neo4j setup
driver = neo4j.GraphDatabase.driver(uri="neo4j://neo4j:7687", auth=("neo4j","ucb_mids_w205"))
session = driver.session(database="neo4j")

# Functions for interacting with and building graph databases, from labs

def my_neo4j_wipe_out_database():
    "wipe out database by deleting all nodes and relationships"
    
    query = "match (node)-[relationship]->() delete node, relationship"
    session.run(query)
    
    query = "match (node) delete node"
    session.run(query)
def my_neo4j_run_query_pandas(query, **kwargs):
    "run a query and return the results in a pandas dataframe"
    
    result = session.run(query, **kwargs)
    
    df = pd.DataFrame([r.values() for r in result], columns=result.keys())
    
    return df
def my_neo4j_number_nodes_relationships():
    "print the number of nodes and relationships"
   
    
    query = """
        match (n) 
        return n.name as node_name, labels(n) as labels
        order by n.name
    """
    
    df = my_neo4j_run_query_pandas(query)
    
    number_nodes = df.shape[0]
    
    
    query = """
        match (n1)-[r]->(n2) 
        return n1.name as node_name_1, labels(n1) as node_1_labels, 
            type(r) as relationship_type, n2.name as node_name_2, labels(n2) as node_2_labels
        order by node_name_1, node_name_2
    """
    
    df = my_neo4j_run_query_pandas(query)
    
    number_relationships = df.shape[0]
    
    print("-------------------------")
    print("  Nodes:", number_nodes)
    print("  Relationships:", number_relationships)
    print("-------------------------")
def my_neo4j_create_node(node_name):
    "create a node with label Name"
    
    query = """
    
    CREATE (:Name {name: $node_name})
    
    """
    
    session.run(query, node_name=node_name)
def my_neo4j_create_relationship_one_way(from_node, to_node, weight):
    "create a relationship one way between two nodes with a weight"
    
    query = """
    
    MATCH (from:Name), 
          (to:Name)
    WHERE from.name = $from_node and to.name = $to_node
    CREATE (from)-[:LINK {weight: $weight}]->(to)
    
    """
    
    session.run(query, from_node=from_node, to_node=to_node, weight=weight)
def my_neo4j_create_relationship_two_way(from_node, to_node, weight):
    "create relationships two way between two nodes with a weight"
    
    query = """
    
    MATCH (from:Name), 
          (to:Name)
    WHERE from.name = $from_node and to.name = $to_node
    CREATE (from)-[:LINK {weight: $weight}]->(to),
           (to)-[:LINK {weight: $weight}]->(from)
    
    """
    
    session.run(query, from_node=from_node, to_node=to_node, weight=weight)

# %%
# Make graph database

# Delete the database if it already exists
my_neo4j_wipe_out_database()

# Make a node for each school and each unique category
# ex: my_neo4j_create_node('Alaska Career College - Anchorage')

# Add a node for each unique school name
school_names = set(all_schools['Company name'])
for school in school_names:
    #print(school)
    my_neo4j_create_node(school)

# Create a category node for each Segment, exclude nans
segments = set(all_schools['Segment'].dropna())
for segment in segments:
    if segment != np.nan:
        #print(segment)
        my_neo4j_create_node(segment)

# Create a category node for each School Type, exclude nans
school_types = set(all_schools['School Type (picklist)'].dropna())
for school_type in school_types:
    #print(school_type)
    my_neo4j_create_node(school_type)

# Create a category node for greater than or less than 150 students
my_neo4j_create_node('gte_150_students')
my_neo4j_create_node('lt_150_students')

# Create a category node for each LMS, exclude nans
# Can be multiple values, split on ; and ,
lmss = set(all_schools['LMS (multi-select)'].dropna())

all_lms_values = []
for lms in lmss:
    split_values = lms.replace(';',',').split(',')
    all_lms_values.extend(split_values)

final_lms_values = []
for lms in list(set(all_lms_values)):
    #print(list(set(all_lms_values)))
    lms_norm = lms.strip()
    if lms_norm != np.nan and lms_norm not in final_lms_values:
        my_neo4j_create_node(lms_norm)
        final_lms_values.append(lms_norm)
        
for lms in sorted(final_lms_values):
    print(lms)
# Out:
# Blackboard
# Blue Triangle
# BrightSpace by D2L
# Brighthouse
# Brightspace
# CLIC
# CLIC ( Proprietary)
# CLIC (Certified Learing in Education)
# Canvas
# Cengage
# Clic
# Clic/Homegrown
# Clic/Proprietary
# College Office
# Custom
# D2L
# Ellucian
# Evolve Elsevier
# Google Classroom
# Google Classroom/Schoololgy
# Google classroom
# Home grown
# Jupiter
# Jupiter Ed
# KlassApp
# Klassapp
# LA Film Online
# LERN
# LearnAveda
# MS365
# Microsoft
# Microsoft Office 365
# Microsoft Teams
# Milady
# Moodle
# NEO
# None
# Open LMS (A Moodle Product)
# Open LMS- A moodle product
# Other
# PivotPoint
# Populi
# Powerschool
# Proctorio - https://proctorio.com/
# SAP Netweaver
# Sakai
# Schoology
# Stack Blue
# ThinkWave
# Toni &Guy
# bright space
# googlesuit
# webex
# zoom

# %%
# Create edges between school nodes and category nodes
#my_neo4j_create_relationship_one_way(school, category, weight)

for i, school in all_schools.iterrows():
    name = school['Company name']
    segment = school['Segment']
    school_type = school['School Type (picklist)']
    student_gt_150 = school['total_students_gt_150']
    lms = school['LMS (multi-select)']

    # Add edges from school to segment
    if not pd.isna(segment):
        #pass
        #print(name + ' -> ' + segment)
        my_neo4j_create_relationship_one_way(name, segment, 0)

    # Add edges from school to type
    if not pd.isna(school_type):
        #pass
        #print(name + ' -> ' + school_type)
        my_neo4j_create_relationship_one_way(name, school_type, 0) 
    
    # Add edges from school to nodes indicating greater than or equal to 150 students
    #  or less than 150 students
    if student_gt_150:
        #pass
        #print(name + ' -> ' + 'gte_150_students')
        my_neo4j_create_relationship_one_way(name, 'gte_150_students', 0)
    else:
        #pass
        #print(name + ' -> ' + 'lt_150_students')
        my_neo4j_create_relationship_one_way(name, 'lt_150_students', 0)

    # Add edges from school to each LMS system they support
    if not pd.isna(lms):
        all_lms_values = lms.replace(';',',').split(',')

        for val in all_lms_values:
            #pass
            #print(name + ' -> ' + val.strip())
            my_neo4j_create_relationship_one_way(name, val.strip(), 0)

# %%
# Node Similarity

def my_neo4j_node_similarity():
    """
    Run the node similarity algorithm on the school graph
    """
    
    # Drop existing projection
    query = "CALL gds.graph.drop('school_graph', false)"
    session.run(query)

    # Create new in-memory projection
    query = """
    CALL gds.graph.project(
        'school_graph',
        'Name', 
        'LINK',
        {relationshipProperties: 'weight'}
    )
    """
    session.run(query)

    # Run the node similarity algorithm
    query = """
    CALL gds.nodeSimilarity.stream('school_graph', {similarityCutoff: 0.25})
    YIELD node1, node2, similarity
    RETURN
        gds.util.asNode(node1).name AS from,
        gds.util.asNode(node2).name AS to,
        similarity
    ORDER BY similarity DESCENDING, from, to

    """
    result = session.run(query)
    
    sim_data = [r.data() for r in result]
    sim_data_df = pd.DataFrame(sim_data)
    
    return sim_data_df
    
#     for r in result:
#         print(f"{r['from']} - {r['to']}: {r['similarity']}")
        
ns_df = my_neo4j_node_similarity()

# Look at similarities to some of the best customers
#for company in happiest['Company name']:
for i, company in happiest.iterrows():
    name = company['Company name']
    segment = company['Segment']
    school_type = company['School Type (picklist)']
    lms = company['LMS (multi-select)']
    
    
    # build dataframe of companies compared to this exemplar
    comp_compare = ns_df[ns_df['to'] == name]
    
    if len(comp_compare) == 0:
        continue
    
    print(f"{name} ({segment} | {school_type} | {lms})")
    
    # Print the stats for each similar school to illustrate the similarities/differences
    for i, row in comp_compare.iterrows():
        comp_name = row['from']
        comp_similarity = row['similarity']
        
        comp_row = all_schools.loc[all_schools['Company name'] == comp_name]
        segment = comp_row['Segment'].iloc[0]
        school_type = comp_row['School Type (picklist)'].iloc[0]
        lms = comp_row['LMS (multi-select)'].iloc[0]
        more_than_150 = comp_row['total_students_gt_150'].iloc[0]
        
        print(f"\t({comp_similarity}) {comp_name}")
        print(f"\t\t{segment}")
        print(f"\t\t{school_type}")
        print(f"\t\t{lms}")
        print(f"\t\t{more_than_150}")
    print()
# Out:
# Mildred Elley - Corporate Office (Allied Health | Private for-profit | Moodle)
# 	(1.0) American College of Healthcare and Technology - Corporate Office
# 		Allied Health
# 		Private for-profit
# 		Moodle
# 		True
# 	(1.0) American University of Health Sciences - Hill
# 		Allied Health
# 		Private for-profit
# 		Moodle
# 		True
# 	(1.0) Atlantis University - Miami
# 		Allied Health
# 		Private for-profit
# 		Moodle
# 		True
# 	(1.0) CCI Training Center - Arlington
# 		Allied Health
# 		Private for-profit
# 		Moodle
# 		True
# 	(1.0) Dawn Career Institute LLC - Newark
# 		Allied Health
# 		Private for-profit
# 		Moodle
# 		True
# 	(1.0) Five Branches University - Santa Cruz
# 		Allied Health
# 		Private for-profit
# 		Moodle
# 		True
# 	(1.0) Florida Academy of Nursing
# 		Allied Health
# 		Private for-profit
# 		Moodle
# 		True
# 	(1.0) Florida Education Institute - Miami
# 		Allied Health
# 		Private for-profit
# 		Moodle
# 		True
# 	(1.0) Fox College - Beedford Park
# 		Allied Health
# 		Private for-profit
# 		Moodle
# 		True
# 	(1.0) Infinity College - Lafayette
# 		Allied Health
# 		Private for-profit
# 		Moodle
# 		True
# 	(1.0) Martinsburg College - Martinsburg
# 		Allied Health
# 		Private for-profit
# 		Moodle
# 		True
# 	(1.0) PITC Institute - Wyncote
# 		Allied Health
# 		Private for-profit
# 		Moodle
# 		True
# 	(1.0) Platt College-STVT - San Antonio
# 		Allied Health
# 		Private for-profit
# 		Moodle
# 		True
# 	(1.0) Valley College - Corporate Office
# 		Allied Health
# 		Private for-profit
# 		Moodle
# 		True
# 	(0.8) Healthcare Career College - Paramount
# 		Allied Health
# 		Private for-profit
# 		Canvas; Moodle
# 		True
# 	(0.8) Herzing University - Corporate Office
# 		Allied Health
# 		Private for-profit
# 		Canvas; Moodle
# 		True
# 	(0.8) Institute of Medical Careers - Pittsburgh
# 		Allied Health
# 		Private for-profit
# 		Moodle; Open LMS (A Moodle Product)
# 		True
# 	(0.5714285714285714) Hondros College of Nursing - Corporate
# 		Allied Health
# 		Private for-profit
# 		Sakai; D2L; Moodle; Other
# 		True
#
# Paul Mitchell the School - Colorado Springs (Beauty + Wellness | Private for-profit | PivotPoint)
# 	(1.0) Aveda - Fort Lauderdale
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Aveda Arts - Covington
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Aveda Arts - Lafayette
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Aveda Arts - Minneapolis
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Aveda Arts - New York
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Aveda Fredric's Institute - Cincinnati
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Aveda Fredric's Institute Indianapolis - Carmel
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Aveda Institute - Denver
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Aveda Institute - Jacksonville
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Aveda Institute - Portland
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Aveda Institute - Rochester
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Aveda Institute - San Antonio
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Aveda Institute - Tallahassee
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Aveda Institute - Tampa Bay
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Aveda Institute - Tucson
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Aveda Institute Denver/Provo/Tucson/Phoenix
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Aveda Institute Des Moines
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Aveda Institute Portland - Vancouver, WA Campus
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Aveda Institutes South
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Be Aveda Institute - Brandon
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) California College of Barbering and Cosmetology - Stockton
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Capri College - Corporate Office
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Casal Institute of Nevada - Las Vegas
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Cinta Aveda
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Georgia Career Institute - Conyers
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Jean Madeline Aveda Institute - Queen Village
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Moored Beauty School
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) National Beauty College - Corporate Office
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) North Adrian's College of Beauty Inc - Modesto
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) P&A Scholars Beauty School - Detroit
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) PCI Academy - Corporate Office
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Paul Mitchell the School - Boise
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Paul Mitchell the School - Chicago
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Paul Mitchell the School - Las Vegas
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Paul Mitchell the School - Little Rock
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Paul Mitchell the School - Provo
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Paul Mitchell the School - San Diego
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Paul Mitchell the School - St Louis
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Paul Mitchell the School - Wichita
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Penrose Academy - Scottsdale
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Rizzieri Aveda School - Voorhees
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Rob Roy Academy - Corporate Office
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Salon Schools Group
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) The Beauty Institute - Corporate Office
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) The Studio Academy of Beauty
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Toni & Guy Hairdressing Academy - Colorado Springs
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Toni & Guy Hairdressing Academy - Erie
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Toni & Guy Hairdressing Academy - Kellar
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Toni & Guy Hairdressing Academy - Worcester
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Tricoci - Bridgeview
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Tricoci - Chicago NW (Norwood Park)
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Tricoci - Highland
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Tricoci - Indianapolis NE (Fishers)
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Tricoci - Libertyville
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Tricoci - Rockford
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Tricoci - Urbana
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(1.0) Vanguard College of Cosmetology - Corporate Office
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True
# 	(0.8) Aveda Institute Maine - Augusta
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint; KlassApp
# 		True
# 	(0.8) Eric Fisher Academy - Wichita
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint; Klassapp
# 		True
# 	(0.8) Federico Beauty Institute - Sacramento
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady; PivotPoint
# 		True
# 	(0.8) Toni&Guy Hairdressing Academy at Penn Commercial
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint; Toni &Guy
# 		True
# 	(0.6) Innovate Salon Academy - Corporate Office
# 		Beauty + Wellness
# 		Not-for-profit
# 		PivotPoint
# 		True
# 	(0.6) Taylor Andrews Academy of Hair Design - Corporate Office
# 		Beauty + Wellness
# 		Not-for-profit
# 		PivotPoint
# 		True
# 	(0.5) Spa Tech Institute - Corporate Office
# 		Beauty + Wellness
# 		Community College
# 		PivotPoint
# 		True
#
# Platt College - Aurora (Allied Health | Private for-profit | Canvas)
# 	(1.0) Advanced College - Corporate Office
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) Alaska Career College - Anchorage
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) Altierus Career College - Corporate Office
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) American College of Education - Indianapolis
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) Arizona College & Arizona College of Nursing - Corporate Office
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) Azure College
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) Bel - Rea Institute of Animal Technology
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) CDE Career Institute - Tannersville
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) CET - Corporate Office
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) Career Care Institute - Lancaster
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) Center for Allied Health Education - Brooklyn
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) College of Health Careers
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) Contra Costa Medical Career College - Antioch
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) Delta Technical College - Lake
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) Denver College of Nursing - Denver (Main Campus)
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) Eastern International College - Corporate Office
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) Eastwick College - Corporate Office
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) Empire College - Santa Rosa
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) Galen College of Nursing - Corporate Office
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) InterCoast Colleges - Corporate Office
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) International Institute For Health Care Professionals
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) Laurel Technical Institute - Corporate Office
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) Marian Health Careers Center - Corporate Office
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) Medical Training College - Baton Rouge
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) Meridian Institute of Surgical Assisting - Nashville
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) Midwest Institute - Fenton
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) National Career College - Panorama City
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) National Holistic Institute - Emeryville
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) New York School for Medical and Dental Assistants - Long Island City
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) Northwest Career College - Las Vegas
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) PCI Health Training Center - Dallas
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) Rio Grande Valley College
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) Ross Education - Corporate Office
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) South Hills School of Business & Technology - College
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) Southern California Health Institute - Hollywood
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) Southwest Institute of Healing Arts - Tempe
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) St Paul's School of Nursing - Corporate Office
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) Summit College - San Bernardino
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) Swedish Institute a College of Health Sciences - New York
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) Vet Tech Institute - Corporate Office
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) West Coast Ultrasound Institute, School of Imaging - Corporate
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) West Virginia Junior College - Corporate Office
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(1.0) Wichita Technical Institute - Wichita
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		True
# 	(0.8) American Career College - Corporate Office
# 		Allied Health
# 		Private for-profit
# 		Canvas; Blackboard
# 		True
# 	(0.8) Berks Technical Institute
# 		Allied Health
# 		Private for-profit
# 		Canvas; Other
# 		True
# 	(0.75) American Medical Academy - Miami
# 		Allied Health
# 		nan
# 		Canvas
# 		True
# 	(0.6) Woodruff Medical Training and Testing - Corporate Office
# 		Allied Health
# 		Private for-profit
# 		Canvas
# 		False
#
# Solano Community College - Fairfield (Allied Health | Community College | Canvas)
# 	(1.0) Ambria College of Nursing - Hoffman Estates
# 		Allied Health
# 		Community College
# 		Canvas
# 		True
# 	(1.0) Angeles College
# 		Allied Health
# 		Community College
# 		Canvas
# 		True
# 	(1.0) Beal University - Bangor
# 		Allied Health
# 		Community College
# 		Canvas
# 		True
# 	(1.0) Bellingham Technical College - Bellingham
# 		Allied Health
# 		Community College
# 		Canvas
# 		True
# 	(1.0) Carolinas College of Health Sciences - Charlotte
# 		Allied Health
# 		Community College
# 		Canvas
# 		True
# 	(1.0) Felbry College School of Nursing - Columbus
# 		Allied Health
# 		Community College
# 		Canvas
# 		True
# 	(1.0) NUC University - Bayamon
# 		Allied Health
# 		Community College
# 		Canvas
# 		True
# 	(1.0) Sumner College - Portland
# 		Allied Health
# 		Community College
# 		Canvas
# 		True
# 	(0.8) Community HigherEd
# 		Community College
# 		Community College
# 		Canvas
# 		True
# 	(0.8) Pacific College - Mesa
# 		Allied Health
# 		Community College
# 		nan
# 		True
# 	(0.6666666666666666) Platt College-STVT - McAllen
# 		Allied Health
# 		Community College
# 		Moodle
# 		True
# 	(0.6666666666666666) Southwest University - El Paso
# 		Allied Health
# 		Community College
# 		Moodle
# 		True
# 	(0.5714285714285714) Daytona College - Ormond Beach
# 		Allied Health
# 		Community College
# 		Blackboard; Jupiter
# 		True
# 	(0.5714285714285714) Santa Barbara City College - Santa Barbara
# 		Community College
# 		Public
# 		Canvas; PivotPoint
# 		True
#
# BOCES - Onondaga-Cortland-Madison Counties (Allied Health | Public | Blackboard)
# 	(1.0) Eastern Suffolk BOCES - Corporate Office
# 		Allied Health
# 		Public
# 		Blackboard
# 		True
# 	(1.0) Immokalee Technical College - Immokalee
# 		Allied Health
# 		Public
# 		Blackboard
# 		True
# 	(1.0) Lakeshore Technical College - Cleveland
# 		Allied Health
# 		Public
# 		Blackboard
# 		True
# 	(1.0) Savannah Technical College - Savannah
# 		Allied Health
# 		Public
# 		Blackboard
# 		True
# 	(1.0) Southeastern Technical College - Vidalia
# 		Allied Health
# 		Public
# 		Blackboard
# 		True
# 	(1.0) Tulsa Technology Center - Tulsa
# 		Allied Health
# 		Public
# 		Blackboard
# 		True
#
# California Healing Arts College - Carson (Allied Health | Private for-profit | None)
# 	(1.0) American Training Center
# 		Allied Health
# 		Private for-profit
# 		None
# 		True
# 	(1.0) Center for Ultrasound Research & Education - Plains
# 		Allied Health
# 		Private for-profit
# 		None
# 		True
# 	(1.0) Dayton School of Medical Massage - Dayton
# 		Allied Health
# 		Private for-profit
# 		None
# 		True
# 	(1.0) Taylor College - Belleview
# 		Allied Health
# 		Private for-profit
# 		None
# 		True
#
# Midwestern Career College - Corporate Office (Allied Health | Private for-profit | D2L)
# 	(1.0) ATA Career Education - Spring Hill
# 		Allied Health
# 		Private for-profit
# 		D2L
# 		True
# 	(1.0) ATA College - Corporate Office
# 		Allied Health
# 		Private for-profit
# 		D2L
# 		True
# 	(1.0) Century College - Corporate Office
# 		Allied Health
# 		Private for-profit
# 		D2L
# 		True
# 	(1.0) Delta College
# 		Allied Health
# 		Private for-profit
# 		D2L
# 		True
# 	(1.0) Gwinnett College - Corporate Office
# 		Allied Health
# 		Private for-profit
# 		D2L
# 		True
# 	(1.0) IBMC College - Collins
# 		Allied Health
# 		Private for-profit
# 		D2L
# 		True
# 	(1.0) South University - Corporate Office
# 		Allied Health
# 		Private for-profit
# 		D2L
# 		True
# 	(0.8) AMG School of Licensed Practical Nursing - Brooklyn
# 		Allied Health
# 		Private for-profit
# 		D2L; bright space
# 		True
# 	(0.8) American Institute of Medical Sciences & Education - Piscataway
# 		Allied Health
# 		Private for-profit
# 		D2L; BrightSpace by D2L
# 		True
# 	(0.8) WellSpring School of Allied Health - Corporate Office
# 		Allied Health
# 		Private for-profit
# 		D2L; Brightspace
# 		True
# 	(0.6666666666666666) MDT College of Health Sciences - Heights
# 		Allied Health
# 		Private for-profit
# 		D2L; Brighthouse; College Office
# 		True
# 	(0.5714285714285714) Hondros College of Nursing - Corporate
# 		Allied Health
# 		Private for-profit
# 		Sakai; D2L; Moodle; Other
# 		True
#
# Paul Mitchell the School - Arlington (Beauty + Wellness | Private for-profit | Milady)
# 	(1.0) Atlanta School of Massage - Atlanta
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Elaine Sterling Institute - Atlanta
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Houston Barber School - Corporate
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Houston Training School - Corporate Office
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) International School of Skin Nailcare & Massage Therapy - Atlanta
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Dallas
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Denver
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Fresno
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Houston
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Memphis
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Michigan
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Modesto
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Overland Park
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Roanoke
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Salt Lake City
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - San Antonio
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Tulsa
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) San Francisco Institute of Esthetics & Cosmetology Inc (PMTS Partner)
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(0.8) Avalon School of Cosmetology - Corporate Office
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady; Moodle
# 		True
# 	(0.8) Empire Beauty School - Hooksett
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady; CLIC ( Proprietary)
# 		True
# 	(0.42857142857142855) South Dade Technical College
# 		Beauty + Wellness
# 		Public
# 		Milady; Canvas; Cengage
# 		True
#
# Paul Mitchell the School - Denver (Beauty + Wellness | Private for-profit | Milady)
# 	(1.0) Atlanta School of Massage - Atlanta
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Elaine Sterling Institute - Atlanta
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Houston Barber School - Corporate
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Houston Training School - Corporate Office
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) International School of Skin Nailcare & Massage Therapy - Atlanta
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Arlington
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Dallas
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Fresno
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Houston
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Memphis
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Michigan
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Modesto
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Overland Park
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Roanoke
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Salt Lake City
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - San Antonio
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Tulsa
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) San Francisco Institute of Esthetics & Cosmetology Inc (PMTS Partner)
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(0.8) Avalon School of Cosmetology - Corporate Office
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady; Moodle
# 		True
# 	(0.8) Empire Beauty School - Hooksett
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady; CLIC ( Proprietary)
# 		True
#
# Paul Mitchell the School - Fresno (Beauty + Wellness | Private for-profit | Milady)
# 	(1.0) Atlanta School of Massage - Atlanta
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Elaine Sterling Institute - Atlanta
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Houston Barber School - Corporate
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Houston Training School - Corporate Office
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) International School of Skin Nailcare & Massage Therapy - Atlanta
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Arlington
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Dallas
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Denver
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Houston
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Memphis
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Michigan
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Modesto
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Overland Park
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Roanoke
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Salt Lake City
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - San Antonio
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Tulsa
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) San Francisco Institute of Esthetics & Cosmetology Inc (PMTS Partner)
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(0.8) Avalon School of Cosmetology - Corporate Office
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady; Moodle
# 		True
# 	(0.8) Empire Beauty School - Hooksett
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady; CLIC ( Proprietary)
# 		True
# 	(0.42857142857142855) South Dade Technical College
# 		Beauty + Wellness
# 		Public
# 		Milady; Canvas; Cengage
# 		True
#
# Paul Mitchell the School - Houston (Beauty + Wellness | Private for-profit | Milady)
# 	(1.0) Atlanta School of Massage - Atlanta
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Elaine Sterling Institute - Atlanta
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Houston Barber School - Corporate
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Houston Training School - Corporate Office
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) International School of Skin Nailcare & Massage Therapy - Atlanta
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Arlington
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Dallas
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Denver
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Fresno
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Memphis
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Michigan
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Modesto
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Overland Park
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Roanoke
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Salt Lake City
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - San Antonio
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Tulsa
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) San Francisco Institute of Esthetics & Cosmetology Inc (PMTS Partner)
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(0.8) Avalon School of Cosmetology - Corporate Office
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady; Moodle
# 		True
# 	(0.8) Empire Beauty School - Hooksett
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady; CLIC ( Proprietary)
# 		True
#
# Paul Mitchell the School - Modesto (Beauty + Wellness | Private for-profit | Milady)
# 	(1.0) Atlanta School of Massage - Atlanta
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Elaine Sterling Institute - Atlanta
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Houston Barber School - Corporate
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Houston Training School - Corporate Office
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) International School of Skin Nailcare & Massage Therapy - Atlanta
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Arlington
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Dallas
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Denver
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Fresno
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Houston
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Memphis
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Michigan
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Overland Park
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Roanoke
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Salt Lake City
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - San Antonio
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Tulsa
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) San Francisco Institute of Esthetics & Cosmetology Inc (PMTS Partner)
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(0.8) Avalon School of Cosmetology - Corporate Office
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady; Moodle
# 		True
# 	(0.8) Empire Beauty School - Hooksett
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady; CLIC ( Proprietary)
# 		True
#
# Paul Mitchell the School - Overland Park (Beauty + Wellness | Private for-profit | Milady)
# 	(1.0) Atlanta School of Massage - Atlanta
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Elaine Sterling Institute - Atlanta
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Houston Training School - Corporate Office
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Arlington
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Denver
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Fresno
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Houston
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Modesto
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Roanoke
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Salt Lake City
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
#
# Paul Mitchell the School - Roanoke (Beauty + Wellness | Private for-profit | Milady)
# 	(1.0) Atlanta School of Massage - Atlanta
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Elaine Sterling Institute - Atlanta
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Houston Barber School - Corporate
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Houston Training School - Corporate Office
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) International School of Skin Nailcare & Massage Therapy - Atlanta
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Arlington
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Dallas
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Denver
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Fresno
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Houston
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Memphis
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Michigan
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Modesto
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Overland Park
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Salt Lake City
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - San Antonio
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Tulsa
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) San Francisco Institute of Esthetics & Cosmetology Inc (PMTS Partner)
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(0.8) Avalon School of Cosmetology - Corporate Office
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady; Moodle
# 		True
# 	(0.8) Empire Beauty School - Hooksett
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady; CLIC ( Proprietary)
# 		True
# 	(0.8) Federico Beauty Institute - Sacramento
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady; PivotPoint
# 		True
# 	(0.42857142857142855) South Dade Technical College
# 		Beauty + Wellness
# 		Public
# 		Milady; Canvas; Cengage
# 		True
#
# Paul Mitchell the School - Salt Lake City (Beauty + Wellness | Private for-profit | Milady)
# 	(1.0) Atlanta School of Massage - Atlanta
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Elaine Sterling Institute - Atlanta
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Houston Barber School - Corporate
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Houston Training School - Corporate Office
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) International School of Skin Nailcare & Massage Therapy - Atlanta
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Arlington
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Dallas
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Denver
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Fresno
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Houston
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Memphis
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Michigan
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Modesto
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Overland Park
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Roanoke
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - San Antonio
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) Paul Mitchell the School - Tulsa
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(1.0) San Francisco Institute of Esthetics & Cosmetology Inc (PMTS Partner)
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		True
# 	(0.8) Avalon School of Cosmetology - Corporate Office
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady; Moodle
# 		True
# 	(0.8) Empire Beauty School - Hooksett
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady; CLIC ( Proprietary)
# 		True
#
# Santa Barbara City College - Santa Barbara (Community College | Public | Canvas; PivotPoint)
# 	(0.5714285714285714) Spa Tech Institute - Corporate Office
# 		Beauty + Wellness
# 		Community College
# 		PivotPoint
# 		True
#
# DeHart Technical School - Modesto (Career + Trade | Private for-profit | None)
# 	(0.75) Platt College - San Diego
# 		Career + Trade
# 		Private for-profit
# 		nan
# 		False
# 	(0.3333333333333333) Bergen County Technical Schools
# 		Career + Trade
# 		Public
# 		Google Classroom
# 		False
#
# Paul Mitchell the School - Arkansas (Beauty + Wellness | Private for-profit | Milady)
# 	(1.0) Academy for Salon Professionals
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) ESI - Westminster
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Clear Lake
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Grand Rapids
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Great Lakes
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Madison
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Miami
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Phoenix
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Altoona
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Cedar Falls
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Colorado Springs
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Fargo
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Fort Myers
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Holland
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Nampa
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(0.75) The Salon Professional Academy - Collegeville
# 		Beauty + Wellness
# 		nan
# 		Milady
# 		False
#
# Paul Mitchell the School - Clear Lake (Beauty + Wellness | Private for-profit | Milady)
# 	(1.0) Academy for Salon Professionals
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) ESI - Westminster
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Arkansas
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Grand Rapids
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Great Lakes
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Madison
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Miami
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Phoenix
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Altoona
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Cedar Falls
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Colorado Springs
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Fargo
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Fort Myers
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Holland
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Nampa
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(0.75) The Salon Professional Academy - Collegeville
# 		Beauty + Wellness
# 		nan
# 		Milady
# 		False
#
# Paul Mitchell the School - Grand Rapids (Beauty + Wellness | Private for-profit | Milady)
# 	(1.0) Academy for Salon Professionals
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) ESI - Westminster
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Arkansas
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Clear Lake
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Great Lakes
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Madison
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Miami
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Phoenix
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Altoona
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Cedar Falls
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Colorado Springs
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Fargo
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Fort Myers
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Holland
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Nampa
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(0.75) The Salon Professional Academy - Collegeville
# 		Beauty + Wellness
# 		nan
# 		Milady
# 		False
#
# Paul Mitchell the School - Great Lakes (Beauty + Wellness | Private for-profit | Milady)
# 	(1.0) Academy for Salon Professionals
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) ESI - Westminster
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Arkansas
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Clear Lake
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Grand Rapids
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Madison
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Miami
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Phoenix
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Altoona
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Cedar Falls
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Colorado Springs
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Fargo
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Fort Myers
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Holland
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Nampa
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(0.75) The Salon Professional Academy - Collegeville
# 		Beauty + Wellness
# 		nan
# 		Milady
# 		False
#
# Paul Mitchell the School - Madison (Beauty + Wellness | Private for-profit | Milady)
# 	(1.0) Academy for Salon Professionals
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) ESI - Westminster
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Arkansas
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Clear Lake
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Grand Rapids
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Great Lakes
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Miami
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Phoenix
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Altoona
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Cedar Falls
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Colorado Springs
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Fargo
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Fort Myers
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Holland
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Nampa
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(0.75) The Salon Professional Academy - Collegeville
# 		Beauty + Wellness
# 		nan
# 		Milady
# 		False
#
# Paul Mitchell the School - Miami (Beauty + Wellness | Private for-profit | Milady)
# 	(1.0) ESI - Westminster
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Arkansas
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Clear Lake
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Grand Rapids
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Great Lakes
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Madison
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Phoenix
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Colorado Springs
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Fargo
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Fort Myers
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
#
# Paul Mitchell the School - Phoenix (Beauty + Wellness | Private for-profit | Milady)
# 	(1.0) Academy for Salon Professionals
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) ESI - Westminster
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Arkansas
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Clear Lake
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Grand Rapids
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Great Lakes
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Madison
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) Paul Mitchell the School - Miami
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Altoona
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Cedar Falls
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Colorado Springs
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Fargo
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Fort Myers
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Holland
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(1.0) The Salon Professional Academy - Nampa
# 		Beauty + Wellness
# 		Private for-profit
# 		Milady
# 		False
# 	(0.75) The Salon Professional Academy - Collegeville
# 		Beauty + Wellness
# 		nan
# 		Milady
# 		False
#
# Paul Mitchell the School - Twin Falls (Beauty + Wellness | Private for-profit | PivotPoint)
# 	(1.0) Aveda Arts - Arlington
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Aveda Arts - Atlanta
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Aveda Arts - Austin
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Aveda Arts - Baton Rouge
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Aveda Arts - Birmingham
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Aveda Arts - Charlotte
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Aveda Arts - Corpus Christi
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Aveda Arts - Dallas
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Aveda Arts - Hammond
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Aveda Arts - Houston
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Aveda Arts - Nashville
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Aveda Arts - New Orleans
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Aveda Arts - Seattle
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Aveda Institute - Boise
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Aveda Institute - Las Vegas
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Aveda Institute - Maryland
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Aveda Institute - New Mexico
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Aveda Institute - Phoenix
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Aveda Institute - Provo
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Aveda Institute - Twin Falls
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Aveda Institute Toronto
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Aveda Means Business
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Brown Aveda Institute (Cleveland East) - Mentor
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Brown Aveda Institute (Cleveland West) - Strongsville
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Casal Aveda Institute - Niles
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Empire Beauty Schools - Rochester
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Jean Madeline Aveda Institute - Neshaminy Mall
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Jean Madeline Aveda Institute - University City
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) O'Briens Aveda Institute - Williston
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Paul Mitchell The School - Norman
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Paul Mitchell the School - Delaware
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Paul Mitchell the School - Lombard
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Paul Mitchell the School - Merrillville
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Paul Mitchell the School - Nampa
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Summit Salon Academy - Gainesville
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Summit Salon Academy - Kokomo
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Summit Salon Academy - Lexington
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Summit Salon Academy - Portland
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) The Institute of Beauty and Wellness - Madison
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) The Salon Professional Academy - Huntsville
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) The Salon Professional Academy - Nashville
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) The Salon Professional Academy - Onalaska
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Toni & Guy Hairdressing Academy - Albuquerque
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Toni & Guy Hairdressing Academy - Atlanta
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Toni & Guy Hairdressing Academy - Coeur d' Alene
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Toni & Guy Hairdressing Academy - Costa Mesa
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Toni & Guy Hairdressing Academy - Cranston
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Toni & Guy Hairdressing Academy - Plano
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Toni & Guy Hairdressing Academy - Rio Rancho
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Toni & Guy Hairdressing Academy - Scottsdale
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Toni & Guy Hairdressing Academy - Seattle
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Tricoci - Bloomington
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Tricoci - Chicago NE (Rogers Park)
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Tricoci - Elgin
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Tricoci - Glendale Heights
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Tricoci - Janesville
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Tricoci - Lafayette
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Tricoci - Normal
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(1.0) Tricoci - Peoria
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		False
# 	(0.8) Aveda Institute - South Florida
# 		Beauty + Wellness
# 		Private for-profit
# 		PivotPoint
# 		True

# %%
# Build a dataframe that lists every prospect school and their similarity score relative to each happiest customer

scores = {}

# Generate lists of happiest and prospect company names
happiest_set = set(happiest['Company name'])
prospect_set = set(prospects['Company name'])

# Initialize all prospect schools with default value
DEFAULT_SCORE = 0.25

for prospect in prospect_set:
    scores[prospect] = DEFAULT_SCORE

# For each comparison to an ideal school, record the score if greater than existing (max function)
for _, similarity in ns_df.iterrows():
    comp_from = similarity['from']
    comp_to = similarity['to']
    similarity_score = similarity['similarity']
    if comp_from in prospect_set and comp_to in happiest_set:
        if similarity_score > scores[comp_from]:
            scores[comp_from] = similarity_score

scores_df = pd.DataFrame(list(scores.items()), columns=['School', 'Score'])
scores_df.to_csv('../data/school_similarity_scores.csv', index=False)
